# %%
import pandas as pd
import numpy as np

import pandas as pd
import numpy as np
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg, lit, udf, when, isnan, count, countDistinct, desc, asc, row_number, monotonically_increasing_id
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity

# %%
# import the data (chunksize returns jsonReader for iteration)
businesses = pd.read_json("Data/yelp_academic_dataset_business.json", lines=True, orient='columns', chunksize=100000)
reviews = pd.read_json("Data/yelp_academic_dataset_review.json", lines=True, orient='columns', chunksize=100000)

# %%
# read the data
for business in businesses:
    business_chunk = business
    break

for review in reviews:
    review_chunk = review
    break

# %%
business_subset = business_chunk[['business_id','name','address', 'categories', 'attributes','stars']]
business_subset = business_subset[business_subset['categories'].str.contains('Restaurant.*')==True].reset_index()

# %%
df_review = review_chunk[['user_id','business_id','stars', 'date']]

# %%
df_restaurant = business_subset[['business_id', 'name', 'address']]
df_restaurant.head()
# Out:
#               business_id                   name              address
# 0  MTSW4McQd7CbVtyjqoe9mw     St Honore Pastries          935 Race St
# 1  CF33F8-E6oudUQ46HnavjQ         Sonic Drive-In        615 S Main St
# 2  k0hlBqXX-Bt0vf1op7Jr1w  Tsevi's Pub And Grill    8025 Mackenzie Rd
# 3  bBDDEgkFA1Otx9Lfe7BZUQ         Sonic Drive-In  2312 Dickerson Pike
# 4  eEOYSgkmpB90uNA7lDOMRA  Vietnamese Food Truck

# %%
all_combined = pd.merge(df_review, df_restaurant, on='business_id')
all_combined.head()
# Out:
#                   user_id             business_id  stars                date  \
# 0  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw      3 2018-07-07 22:09:11
# 1  Iaee7y6zdSB3B-kRCo4z1w  XQfwVwDr-v0ZS3_CbbE5Xw      2 2017-05-13 17:06:55
# 2  ejFxLGqQcWNLdNByJlIhnQ  XQfwVwDr-v0ZS3_CbbE5Xw      4 2017-08-08 00:58:18
# 3  f7xa0p_1V9lx53iIGN5Sug  XQfwVwDr-v0ZS3_CbbE5Xw      3 2017-11-19 02:20:23
# 4  dCooFVCk8M1nVaQqcfTL3Q  XQfwVwDr-v0ZS3_CbbE5Xw      2 2017-09-09 17:49:47
#
#                            name              address
# 0  Turning Point of North Wales  1460 Bethlehem Pike
# 1  Turning Point of North Wales  1460 Bethlehem Pike
# 2  Turning Point of North Wales  1460 Bethlehem Pike
# 3  Turning Point of North Wales  1460 Bethlehem Pike
# 4  Turning Point of North Wales  1460 Bethlehem Pike

# %%
all_combined.shape
# Out:
# (72125, 6)

# %%
# create a user-item matrix
rating_crosstab = all_combined.pivot_table(values='stars', index='user_id', columns='name', fill_value=0)
rating_crosstab.head()
# Out:
# name                    'feine  101 Taiwanese Cuisine  10th Street Italian  \
# user_id
# ---2PmXbF47D870stH1jqA     0.0                    0.0                  0.0
# --4AjktZiHowEIBCMd4CZA     0.0                    0.0                  0.0
# --E0uVPphTORm_OiZ5KCvA     0.0                    0.0                  0.0
# --KMTwCrhKKUmr7riuS4WQ     0.0                    0.0                  0.0
# --S8M395r8NtOCvS2LRfDw     0.0                    0.0                  0.0
#
# name                    1200 Chophouse  12th & Porter  16th Street Seafood  \
# user_id
# ---2PmXbF47D870stH1jqA             0.0            0.0                  0.0
# --4AjktZiHowEIBCMd4CZA             0.0            0.0                  0.0
# --E0uVPphTORm_OiZ5KCvA             0.0            0.0                  0.0
# --KMTwCrhKKUmr7riuS4WQ             0.0            0.0                  0.0
# --S8M395r8NtOCvS2LRfDw             0.0            0.0                  0.0
#
# name                    1911 Smoke House Barbeque  1925 Cocktail Lounge  \
# user_id
# ---2PmXbF47D870stH1jqA                        0.0                   0.0
# --4AjktZiHowEIBCMd4CZA                        0.0                   0.0
# --E0uVPphTORm_OiZ5KCvA                        0.0                   0.0
# --KMTwCrhKKUmr7riuS4WQ                        0.0                   0.0
# --S8M395r8NtOCvS2LRfDw                        0.0                   0.0
#
# name                    2 in One Cafe  211 York  ...  eegee's  \
# user_id                                          ...
# ---2PmXbF47D870stH1jqA            0.0       0.0  ...      0.0
# --4AjktZiHowEIBCMd4CZA            0.0       0.0  ...      0.0
# --E0uVPphTORm_OiZ5KCvA            0.0       0.0  ...      0.0
# --KMTwCrhKKUmr7riuS4WQ            0.0       0.0  ...      0.0
# --S8M395r8NtOCvS2LRfDw            0.0       0.0  ...      0.0
#
# name                    fat Rooster diner  honeygrow  iCafe  iLuv Pho  \
# user_id
# ---2PmXbF47D870stH1jqA                0.0        0.0    0.0       0.0
# --4AjktZiHowEIBCMd4CZA                0.0        0.0    0.0       0.0
# --E0uVPphTORm_OiZ5KCvA                0.0        0.0    0.0       0.0
# --KMTwCrhKKUmr7riuS4WQ                0.0        0.0    0.0       0.0
# --S8M395r8NtOCvS2LRfDw                0.0        0.0    0.0       0.0
#
# name                    iPho Vietnamese Restaurant  il Tavolo Trattoria  \
# user_id
# ---2PmXbF47D870stH1jqA                         0.0                  0.0
# --4AjktZiHowEIBCMd4CZA                         0.0                  0.0
# --E0uVPphTORm_OiZ5KCvA                         0.0                  0.0
# --KMTwCrhKKUmr7riuS4WQ                         0.0                  0.0
# --S8M395r8NtOCvS2LRfDw                         0.0                  0.0
#
# name                    la Madeleine  swah-rey  sweetgreen
# user_id
# ---2PmXbF47D870stH1jqA           0.0       0.0         0.0
# --4AjktZiHowEIBCMd4CZA           0.0       0.0         0.0
# --E0uVPphTORm_OiZ5KCvA           0.0       0.0         0.0
# --KMTwCrhKKUmr7riuS4WQ           0.0       0.0         0.0
# --S8M395r8NtOCvS2LRfDw           0.0       0.0         0.0
#
# [5 rows x 3410 columns]

# %%
# Transpose the Utility matrix
X = rating_crosstab.values.T

# %%
def calculate_similarity(user_item_matrix):
    """
    Calculate the cosine similarity matrix from the user-item matrix
    """
    similarity = cosine_similarity(user_item_matrix)
    np.fill_diagonal(similarity, 0)
    return pd.DataFrame(similarity, index=user_item_matrix.index, columns=user_item_matrix.index)

# Prediction of Ratings 

def predict_ratings(similarity, user_item_matrix, user_id):
    """
    Predict ratings for all items for a given user
    """
    total_similarity = similarity[user_id].sum()
    weighted_sum = np.dot(similarity[user_id], user_item_matrix.fillna(0))

    # Avoid division by zero
    if total_similarity == 0:
        total_similarity = 1

    predictions = weighted_sum / total_similarity
    predictions = pd.Series(predictions, index=user_item_matrix.columns)
    return predictions

def train_test_split_and_predict(data):
    """
    Split the data into train and test sets, predict ratings, and return the true and predicted ratings
    """
    train_user_item_matrix, test_user_item_matrix = train_test_split(data, test_size=0.02)

    similarity = calculate_similarity(train_user_item_matrix)
    true_ratings = []
    pred_ratings = []

    for user_id in test_user_item_matrix.index:
        if user_id in test_user_item_matrix.index:
            true_rating = test_user_item_matrix.loc[user_id]
            pred_rating = predict_ratings(similarity, train_user_item_matrix, user_id)
            true_ratings.extend(true_rating[true_rating.notnull()])
            pred_ratings.extend(pred_rating[true_rating.notnull()])

    return true_ratings, pred_ratings

def evaluate_performance(data):
    """
    Evaluate the performance of the collaborative filtering algorithm
    """
    true_ratings, pred_ratings = train_test_split_and_predict(data)
    rmse = np.sqrt(mean_squared_error(true_ratings, pred_ratings))
    mae = mean_absolute_error(true_ratings, pred_ratings)
    return rmse, mae

# %%
rmse, mae = evaluate_performance(rating_crosstab)
print(f'RMSE: {rmse}, MAE: {mae}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/envs/hw2/lib/python3.12/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FkaBNfCc2dRyQ2qXhsXXtg'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/bhavinr/Desktop/Intro To Machine Learning/ML Project/Yelp_Recommendation/kaggleCollaborative.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> rmse, mae = evaluate_performance(rating_crosstab)
#       <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> print(f'RMSE: {rmse}, MAE: {mae}')
#
# /Users/bhavinr/Desktop/Intro To Machine Learning/ML Project/Yelp_Recommendation/kaggleCollaborative.ipynb Cell 12 line 4
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=43'>44</a> def evaluate_performance(data):
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=44'>45</a>     """
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=45'>46</a>     Evaluate the performance of the collaborative filtering algorithm
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=46'>47</a>     """
# ---> <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=47'>48</a>     true_ratings, pred_ratings = train_test_split_and_predict(data)
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=48'>49</a>     rmse = np.sqrt(mean_squared_error(true_ratings, pred_ratings))
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=49'>50</a>     mae = mean_absolute_error(true_ratings, pred_ratings)
#
# /Users/bhavinr/Desktop/Intro To Machine Learning/ML Project/Yelp_Recommendation/kaggleCollaborative.ipynb Cell 12 line 3
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=35'>36</a> for user_id in test_user_item_matrix.index:
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=36'>37</a>     true_rating = test_user_item_matrix.loc[user_id]
# ---> <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=37'>38</a>     pred_rating = predict_ratings(similarity, train_user_item_matrix, user_id)
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=38'>39</a>     true_ratings.extend(true_rating[true_rating.notnull()])
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=39'>40</a>     pred_ratings.extend(pred_rating[true_rating.notnull()])
#
# /Users/bhavinr/Desktop/Intro To Machine Learning/ML Project/Yelp_Recommendation/kaggleCollaborative.ipynb Cell 12 line 1
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a> def predict_ratings(similarity, user_item_matrix, user_id):
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a>     """
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=12'>13</a>     Predict ratings for all items for a given user
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=13'>14</a>     """
# ---> <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=14'>15</a>     total_similarity = similarity[user_id].sum()
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=15'>16</a>     weighted_sum = np.dot(similarity[user_id], user_item_matrix.fillna(0))
#      <a href='vscode-notebook-cell:/Users/bhavinr/Desktop/Intro%20To%20Machine%20Learning/ML%20Project/Yelp_Recommendation/kaggleCollaborative.ipynb#X14sZmlsZQ%3D%3D?line=17'>18</a>     # Avoid division by zero
#
# File ~/mambaforge/envs/hw2/lib/python3.12/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File ~/mambaforge/envs/hw2/lib/python3.12/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'FkaBNfCc2dRyQ2qXhsXXtg'
